# %%
import pandas

# %%
data = None
with open("highway_data.csv") as f:
  data = pandas.read_csv(f)

# %%
import pandera as pa
from pandera import Column, Check

# %%
crash_df = data[data["Record Type"] == 1]
vehicle_df = data[data["Record Type"] == 2]
people_df = data[data["Record Type"] == 3]

# %%
crash_schema = pa.DataFrameSchema(
    {
      "Crash ID": Column(int, unique=True), 
      "Record Type": Column(int, Check.in_range(1,3)),
      "Crash Year": Column(int, Check.eq(2019), coerce=True)
    }
)
crash_schema.validate(crash_df)
# Out:
#       Crash ID  Record Type  Vehicle ID  Participant ID  \
# 0      1809119            1         NaN             NaN
# 5      1809229            1         NaN             NaN
# 9      1809637            1         NaN             NaN
# 12     1810874            1         NaN             NaN
# 16     1812266            1         NaN             NaN
# ...        ...          ...         ...             ...
# 2716   1860371            1         NaN             NaN
# 2719   1860417            1         NaN             NaN
# 2724   1860427            1         NaN             NaN
# 2729   1860453            1         NaN             NaN
# 2734   1860771            1         NaN             NaN
#
#       Participant Display Seq#  Vehicle Coded Seq#  Participant Vehicle Seq#  \
# 0                          NaN                 NaN                       NaN
# 5                          NaN                 NaN                       NaN
# 9                          NaN                 NaN                       NaN
# 12                         NaN                 NaN                       NaN
# 16                         NaN                 NaN                       NaN
# ...                        ...                 ...                       ...
# 2716                       NaN                 NaN                       NaN
# 2719                       NaN                 NaN                       NaN
# 2724                       NaN                 NaN                       NaN
# 2729                       NaN                 NaN                       NaN
# 2734                       NaN                 NaN                       NaN
#
#       Serial #  Crash Month  Crash Day  ...  Participant Cause 2 Code  \
# 0      99992.0          3.0       14.0  ...                       NaN
# 5       2405.0          3.0        3.0  ...                       NaN
# 9       1811.0          5.0       17.0  ...                       NaN
# 12     99981.0          4.0        7.0  ...                       NaN
# 16      5970.0          7.0        8.0  ...                       NaN
# ...        ...          ...        ...  ...                       ...
# 2716    3344.0          4.0       19.0  ...                       NaN
# 2719    3385.0          4.0       20.0  ...                       NaN
# 2724    3396.0          4.0       13.0  ...                       NaN
# 2729    3423.0          4.0       22.0  ...                       NaN
# 2734    1465.0          5.0        6.0  ...                       NaN
#
#       Participant Cause 3 Code  Participant Event 1 Code  \
# 0                          NaN                       NaN
# 5                          NaN                       NaN
# 9                          NaN                       NaN
# 12                         NaN                       NaN
# 16                         NaN                       NaN
# ...                        ...                       ...
# 2716                       NaN                       NaN
# 2719                       NaN                       NaN
# 2724                       NaN                       NaN
# 2729                       NaN                       NaN
# 2734                       NaN                       NaN
#
#       Participant Event 2 Code  Participant Event 3 Code  \
# 0                          NaN                       NaN
# 5                          NaN                       NaN
# 9                          NaN                       NaN
# 12                         NaN                       NaN
# 16                         NaN                       NaN
# ...                        ...                       ...
# 2716                       NaN                       NaN
# 2719                       NaN                       NaN
# 2724                       NaN                       NaN
# 2729                       NaN                       NaN
# 2734                       NaN                       NaN
#
#       BAC Test Results Code  Alcohol Use Reported  Drug Use Reported  \
# 0                       NaN                   NaN                NaN
# 5                       NaN                   NaN                NaN
# 9                       NaN                   NaN                NaN
# 12                      NaN                   NaN                NaN
# 16                      NaN                   NaN                NaN
# ...                     ...                   ...                ...
# 2716                    NaN                   NaN                NaN
# 2719                    NaN                   NaN                NaN
# 2724                    NaN                   NaN                NaN
# 2729                    NaN                   NaN                NaN
# 2734                    NaN                   NaN                NaN
#
#       Participant Marijuana Use Reported  Participant Striker Flag
# 0                                    NaN                       NaN
# 5                                    NaN                       NaN
# 9                                    NaN                       NaN
# 12                                   NaN                       NaN
# 16                                   NaN                       NaN
# ...                                  ...                       ...
# 2716                                 NaN                       NaN
# 2719                                 NaN                       NaN
# 2724                                 NaN                       NaN
# 2729                                 NaN                       NaN
# 2734                                 NaN                       NaN
#
# [508 rows x 157 columns]

# %%
all([x is None or x >= 0 and y >= 0 for (x,y) in list(zip(crash_df["Latitude Degrees"],crash_df["Latitude Minutes"]))])
# Out:
# True

# %%
assert all([x in crash_df["Crash ID"].values for x in vehicle_df["Crash ID"].values])

# %%
counties = list(crash_df["County Code"].values)
(counties.count(3) + counties.count(26) + counties.count(34)) / len(counties)
# Out:
# 0.9429133858267716
