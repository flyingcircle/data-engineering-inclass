# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url)

# %%
import bs4
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Get the title
title = soup.title
print(title)
# Out:
# <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>

# %%
# Print out the text
text = soup.get_text()
#print(soup.text)

# %%
soup.find_all('a')
# Out:
# [<a href="mailto:timing@hubertiming.com">timing@hubertiming.com</a>,
#  <a href="https://www.hubertiming.com">Huber Timing Home</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> 5K Individual</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 5K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 10K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/summary/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i class="fa fa-stream"></i> Summary</a>,
#  <a id="individual" name="individual"></a>,
#  <a data-url="/results/2017GPTR10K" href="#tabs-1" id="rootTab" style="font-size: 18px">10K Results</a>,
#  <a href="https://www.hubertiming.com/"><img height="65" src="https://www.hubertiming.com//sites/all/themes/hubertiming/images/clockWithFinishSign_small.png" width="50"/>Huber Timing</a>,
#  <a href="https://facebook.com/hubertiming/"><img src="https://www.hubertiming.com/results/FB-f-Logo__blue_50.png"/></a>,
#  <a class="small" id="bestFeatureEver" style="color:#007bff">Dark Mode</a>]

# %%
all_links = soup.find_all("a")
for link in all_links:
    print(link.get("href"))
# Out:
# mailto:timing@hubertiming.com
# https://www.hubertiming.com
# /results/2017GPTR
# /results/team/2017GPTR
# /results/team/2017GPTR10K
# /results/summary/2017GPTR10K
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/
# None

# %%
# Print the first 10 rows for sanity check
rows = soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr colspan="2">
# <b>10K:</b>
# </tr>, <tr>
# <td>Finishers:</td>
# <td>577</td>
# </tr>, <tr>
# <td>Male:</td>
# <td>414</td>
# </tr>, <tr>
# <td>Female:</td>
# <td>163</td>
# </tr>, <tr class="header">
# <th>Place</th>
# <th>Bib</th>
# <th>Name</th>
# <th>Gender</th>
# <th>City</th>
# <th>Chip Time</th>
# <th>Gun Time</th>
# <th>Team</th>
# </tr>, <tr data-bib="814">
# <td>1</td>
# <td>814</td>
# <td>
#
#                     JARED WILSON
#
#                 </td>
# <td>M</td>
# <td>TIGARD</td>
# <td>36:21</td>
# <td>36:24</td>
# <td></td>
# </tr>, <tr data-bib="573">
# <td>2</td>
# <td>573</td>
# <td>
#
#                     NATHAN A SUSTERSIC
#
#                 </td>
# <td>M</td>
# <td>PORTLAND</td>
# <td>36:42</td>
# <td>36:45</td>
# <td>
# <img class="lazy teamThumbs" data-src="/teamLogoThumbnail/logo?teamName=INTEL%20TEAM%20F&amp;raceId=1251&amp;state=OR"/>
#                             INTEL TEAM F
#                         </td>
# </tr>, <tr data-bib="687">
# <td>3</td>
# <td>687</td>
# <td>
#
#                     FRANCISCO MAYA
#
#                 </td>
# <td>M</td>
# <td>PORTLAND</td>
# <td>37:44</td>
# <td>37:48</td>
# <td></td>
# </tr>, <tr data-bib="623">
# <td>4</td>
# <td>623</td>
# <td>
#
#                     PAUL MORROW
#
#                 </td>
# <td>M</td>
# <td>BEAVERTON</td>
# <td>38:34</td>
# <td>38:37</td>
# <td></td>
# </tr>, <tr data-bib="569">
# <td>5</td>
# <td>569</td>
# <td>
#
#                     DEREK G OSBORNE
#
#                 </td>
# <td>M</td>
# <td>HILLSBORO</td>
# <td>39:21</td>
# <td>39:24</td>
# <td>
# <img class="lazy teamThumbs" data-src="/teamLogoThumbnail/logo?teamName=INTEL%20TEAM%20F&amp;raceId=1251&amp;state=OR"/>
#                             INTEL TEAM F
#                         </td>
# </tr>]

# %%
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td>577</td>, <td>443</td>, <td>
#
#                     LIBBY B MITCHELL
#
#                 </td>, <td>F</td>, <td>HILLSBORO</td>, <td>1:41:18</td>, <td>1:42:10</td>, <td></td>]
# bs4.element.ResultSet

# %%
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells, "lxml").get_text()
print(cleantext)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, 1:41:18, 1:42:10, ]

# %%
import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = re.sub('\\s+', ' ', str(cells))
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [577, 443,  LIBBY B MITCHELL , F, HILLSBORO, 1:41:18, 1:42:10, ]
# str

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1                                  [Finishers:, 577]
# 2                                       [Male:, 414]
# 3                                     [Female:, 163]
# 4                                                 []
# 5  [1, 814,  JARED WILSON , M, TIGARD, 36:21, 36:...
# 6  [2, 573,  NATHAN A SUSTERSIC , M, PORTLAND, 36...
# 7  [3, 687,  FRANCISCO MAYA , M, PORTLAND, 37:44,...
# 8  [4, 623,  PAUL MORROW , M, BEAVERTON, 38:34, 3...
# 9  [5, 569,  DEREK G OSBORNE , M, HILLSBORO, 39:2...

# %%
df1[0] = df1[0].str.strip('[')
df1.head(10)
# Out:
#             0      1                                                  2     3  \
# 0           ]   None                                               None  None
# 1  Finishers:   577]                                               None  None
# 2       Male:   414]                                               None  None
# 3     Female:   163]                                               None  None
# 4           ]   None                                               None  None
# 5           1    814   \r\n\r\n                    JARED WILSON\r\n\...     M
# 6           2    573   \r\n\r\n                    NATHAN A SUSTERSI...     M
# 7           3    687   \r\n\r\n                    FRANCISCO MAYA\r\...     M
# 8           4    623   \r\n\r\n                    PAUL MORROW\r\n\r...     M
# 9           5    569   \r\n\r\n                    DEREK G OSBORNE\r...     M
#
#             4       5       6  \
# 0        None    None    None
# 1        None    None    None
# 2        None    None    None
# 3        None    None    None
# 4        None    None    None
# 5      TIGARD   36:21   36:24
# 6    PORTLAND   36:42   36:45
# 7    PORTLAND   37:44   37:48
# 8   BEAVERTON   38:34   38:37
# 9   HILLSBORO   39:21   39:24
#
#                                                    7
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]
# 9   \n\r\n                            INTEL TEAM ...

# %%
col_labels = soup.find_all('th')
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ['[Place, Bib, Name, Gender, City, Chip Time, Gun Time, Team]']

# %%
df2 = pd.DataFrame(all_header)
df2.head()
# Out:
#                                                    0
# 0  [Place, Bib, Name, Gender, City, Chip Time, Gu...

# %%
df3 = df2[0].str.split(',', expand=True)
df3.head()
# Out:
#         0     1      2        3      4           5          6       7
# 0  [Place   Bib   Name   Gender   City   Chip Time   Gun Time   Team]

# %%
frames = [df3, df1]

df4 = pd.concat(frames)
df4.head(10)
# Out:
#             0      1                                                  2  \
# 0      [Place    Bib                                               Name
# 0           ]   None                                               None
# 1  Finishers:   577]                                               None
# 2       Male:   414]                                               None
# 3     Female:   163]                                               None
# 4           ]   None                                               None
# 5           1    814   \r\n\r\n                    JARED WILSON\r\n\...
# 6           2    573   \r\n\r\n                    NATHAN A SUSTERSI...
# 7           3    687   \r\n\r\n                    FRANCISCO MAYA\r\...
# 8           4    623   \r\n\r\n                    PAUL MORROW\r\n\r...
#
#          3           4           5          6  \
# 0   Gender        City   Chip Time   Gun Time
# 0     None        None        None       None
# 1     None        None        None       None
# 2     None        None        None       None
# 3     None        None        None       None
# 4     None        None        None       None
# 5        M      TIGARD       36:21      36:24
# 6        M    PORTLAND       36:42      36:45
# 7        M    PORTLAND       37:44      37:48
# 8        M   BEAVERTON       38:34      38:37
#
#                                                    7
# 0                                              Team]
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#        [Place    Bib   Name   Gender   City   Chip Time   Gun Time   Team]
# 0      [Place    Bib   Name   Gender   City   Chip Time   Gun Time   Team]
# 0           ]   None   None     None   None        None       None    None
# 1  Finishers:   577]   None     None   None        None       None    None
# 2       Male:   414]   None     None   None        None       None    None
# 3     Female:   163]   None     None   None        None       None    None

# %%
df5.info()
df5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 583 entries, 0 to 581
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   [Place      583 non-null    object
#  1    Bib        581 non-null    object
#  2    Name       578 non-null    object
#  3    Gender     578 non-null    object
#  4    City       578 non-null    object
#  5    Chip Time  578 non-null    object
#  6    Gun Time   578 non-null    object
#  7    Team]      578 non-null    object
# dtypes: object(8)
# memory usage: 41.0+ KB
# (583, 8)

# %%
df6 = df5.dropna(axis=0, how='any')
df6.info()
df6.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 578 entries, 0 to 581
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   [Place      578 non-null    object
#  1    Bib        578 non-null    object
#  2    Name       578 non-null    object
#  3    Gender     578 non-null    object
#  4    City       578 non-null    object
#  5    Chip Time  578 non-null    object
#  6    Gun Time   578 non-null    object
#  7    Team]      578 non-null    object
# dtypes: object(8)
# memory usage: 40.6+ KB
# (578, 8)

# %%
df7 = df6.drop(df6.index[0])
df7.head()
# Out:
#   [Place   Bib                                               Name  Gender  \
# 5      1   814   \r\n\r\n                    JARED WILSON\r\n\...       M
# 6      2   573   \r\n\r\n                    NATHAN A SUSTERSI...       M
# 7      3   687   \r\n\r\n                    FRANCISCO MAYA\r\...       M
# 8      4   623   \r\n\r\n                    PAUL MORROW\r\n\r...       M
# 9      5   569   \r\n\r\n                    DEREK G OSBORNE\r...       M
#
#          City  Chip Time  Gun Time  \
# 5      TIGARD      36:21     36:24
# 6    PORTLAND      36:42     36:45
# 7    PORTLAND      37:44     37:48
# 8   BEAVERTON      38:34     38:37
# 9   HILLSBORO      39:21     39:24
#
#                                                Team]
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]
# 9   \n\r\n                            INTEL TEAM ...

# %%
df7.rename(columns={'[Place': 'Place'},inplace=True)
df7.rename(columns={' Team]': 'Team'},inplace=True)
df7.head()
# Out:
#   Place   Bib                                               Name  Gender  \
# 5     1   814   \r\n\r\n                    JARED WILSON\r\n\...       M
# 6     2   573   \r\n\r\n                    NATHAN A SUSTERSI...       M
# 7     3   687   \r\n\r\n                    FRANCISCO MAYA\r\...       M
# 8     4   623   \r\n\r\n                    PAUL MORROW\r\n\r...       M
# 9     5   569   \r\n\r\n                    DEREK G OSBORNE\r...       M
#
#          City  Chip Time  Gun Time  \
# 5      TIGARD      36:21     36:24
# 6    PORTLAND      36:42     36:45
# 7    PORTLAND      37:44     37:48
# 8   BEAVERTON      38:34     38:37
# 9   HILLSBORO      39:21     39:24
#
#                                                 Team          Name
# 5
# 6   \n\r\n                            INTEL TEAM ...  INTEL TEAM F
# 7
# 8
# 9   \n\r\n                            INTEL TEAM ...  INTEL TEAM F

# %%
df7['Team'] = df7['Team'].str.strip(']')
df7['Name'] = df7['Name'].str.strip()
df7.head()
# Out:
#   Place   Bib                                               Name  Gender  \
# 5     1   814   \r\n\r\n                    JARED WILSON\r\n\...       M
# 6     2   573   \r\n\r\n                    NATHAN A SUSTERSI...       M
# 7     3   687   \r\n\r\n                    FRANCISCO MAYA\r\...       M
# 8     4   623   \r\n\r\n                    PAUL MORROW\r\n\r...       M
# 9     5   569   \r\n\r\n                    DEREK G OSBORNE\r...       M
#
#          City  Chip Time  Gun Time  \
# 5      TIGARD      36:21     36:24
# 6    PORTLAND      36:42     36:45
# 7    PORTLAND      37:44     37:48
# 8   BEAVERTON      38:34     38:37
# 9   HILLSBORO      39:21     39:24
#
#                                                 Team          Name
# 5
# 6   \n\r\n                            INTEL TEAM ...  INTEL TEAM F
# 7
# 8
# 9   \n\r\n                            INTEL TEAM ...  INTEL TEAM F

# %%
time_list = df7[' Chip Time'].tolist()
time_mins = []
for i in time_list:
    h, m, s = i.split(':')
    math = (int(h) * 3600 + int(m) * 60 + int(s))/60
    time_mins.append(math)
#print(time_mins)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jeremy/Documents/masters/DataEngineering/week2/dataGathering.ipynb Cell 26' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/jeremy/Documents/masters/DataEngineering/week2/dataGathering.ipynb#ch0000027?line=1'>2</a> time_mins = []
#       <a href='vscode-notebook-cell:/Users/jeremy/Documents/masters/DataEngineering/week2/dataGathering.ipynb#ch0000027?line=2'>3</a> for i in time_list:
# ----> <a href='vscode-notebook-cell:/Users/jeremy/Documents/masters/DataEngineering/week2/dataGathering.ipynb#ch0000027?line=3'>4</a>     h, m, s = i.split(':')
#       <a href='vscode-notebook-cell:/Users/jeremy/Documents/masters/DataEngineering/week2/dataGathering.ipynb#ch0000027?line=4'>5</a>     math = (int(h) * 3600 + int(m) * 60 + int(s))/60
#       <a href='vscode-notebook-cell:/Users/jeremy/Documents/masters/DataEngineering/week2/dataGathering.ipynb#ch0000027?line=5'>6</a>     time_mins.append(math)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
df7['Runner_mins'] = time_mins
df7.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jeremy/Documents/masters/DataEngineering/week2/dataGathering.ipynb Cell 27' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jeremy/Documents/masters/DataEngineering/week2/dataGathering.ipynb#ch0000028?line=0'>1</a> df7['Runner_mins'] = time_mins
#       <a href='vscode-notebook-cell:/Users/jeremy/Documents/masters/DataEngineering/week2/dataGathering.ipynb#ch0000028?line=1'>2</a> df7.head()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3651'>3652</a>     self._setitem_array([key], value)
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3652'>3653</a> else:
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3653'>3654</a>     # set column
# -> <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3654'>3655</a>     self._set_item(key, value)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3821'>3822</a> def _set_item(self, key, value) -> None:
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3822'>3823</a>     """
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3823'>3824</a>     Add series to DataFrame in specified column.
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3824'>3825</a>
#    (...)
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3829'>3830</a>     ensure homogeneity.
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3830'>3831</a>     """
# -> <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3831'>3832</a>     value = self._sanitize_column(value)
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3833'>3834</a>     if (
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3834'>3835</a>         key in self.columns
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3835'>3836</a>         and value.ndim == 1
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3836'>3837</a>         and not is_extension_array_dtype(value)
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3837'>3838</a>     ):
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3838'>3839</a>         # broadcast across multiple columns if necessary
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3839'>3840</a>         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:4529, in DataFrame._sanitize_column(self, value)
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=4525'>4526</a>     return _reindex_for_setitem(value, self.index)
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=4527'>4528</a> if is_list_like(value):
# -> <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=4528'>4529</a>     com.require_length_match(value, self.index)
#    <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=4529'>4530</a> return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/common.py:557, in require_length_match(data, index)
#     <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/common.py?line=552'>553</a> """
#     <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/common.py?line=553'>554</a> Check the length of data matches the length of the index.
#     <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/common.py?line=554'>555</a> """
#     <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/common.py?line=555'>556</a> if len(data) != len(index):
# --> <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/common.py?line=556'>557</a>     raise ValueError(
#     <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/common.py?line=557'>558</a>         "Length of values "
#     <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/common.py?line=558'>559</a>         f"({len(data)}) "
#     <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/common.py?line=559'>560</a>         "does not match length of index "
#     <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/common.py?line=560'>561</a>         f"({len(index)})"
#     <a href='file:///Users/jeremy/miniconda3/lib/python3.9/site-packages/pandas/core/common.py?line=561'>562</a>     )
#
# ValueError: Length of values (0) does not match length of index (577)

# %%
df7.describe(include=[np.number])

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 5
df7.boxplot(column='Runner_mins')
plt.grid(True, axis='y')
plt.ylabel('Chip Time')
plt.xticks([1], ['Runners'])

# %%
x = df7['Runner_mins']
ax = sns.distplot(x, hist=True, kde=True, rug=False, color='m', bins=25, hist_kws={'edgecolor':'black'})
plt.show()

# %%
f_fuko = df7.loc[df7[' Gender']==' F']['Runner_mins']
m_fuko = df7.loc[df7[' Gender']==' M']['Runner_mins']
sns.distplot(f_fuko, hist=True, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Female')
sns.distplot(m_fuko, hist=False, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Male')
plt.legend()

# %%
g_stats = df7.groupby(" Gender", as_index=True).describe()
print(g_stats)

# %%
df7.boxplot(column='Runner_mins', by=' Gender')
plt.ylabel('Chip Time')
plt.suptitle("")
